# %%
from bs4 import BeautifulSoup
import requests

# %%
html_text=requests.get('https://www.jumia.ma/catalog/?q=lcd').text

# %%
soup=BeautifulSoup(html_text,'lxml')

# %%
products=soup.find_all('h3',class_= 'name')
for products in product:
    print(products)
    product_price=soup.find('div',class_= 'prc').text
    print(product_price)
    ranking=soup.find('div',class_='stars _s').text
    print(ranking)
    old_price=soup.find('div',class_="old").text.replace(' ','')
    url=
    print(old_price)
# Out:
#   File "<ipython-input-5-d35f9fa5217a>", line 9
#     url=
#         ^
# SyntaxError: invalid syntax

# %%
  print(f'''
    product of jumia:{product}
    price of the products:{product_price}
    ranking of the product:{ranking}
    old price before:{old_price}
    ''')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-2eb37dd70785> in <module>
#       1 print(f'''
# ----> 2   product of jumia:{product}
#       3   price of the products:{product_price}
#       4   ranking of the product:{ranking}
#       5   old price before:{old_price}
#
# NameError: name 'product' is not defined

# %%
print(f"product of jumia:{product}")
print(f"price of the product:{product_price}")
print(f"ranking of the product:{ranking}")
print(f"old price before:{old_price}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-a6a55a4d9a5f> in <module>
# ----> 1 print(f"product of jumia:{product}")
#       2 print(f"price of the product:{product_price}")
#       3 print(f"ranking of the product:{ranking}")
#       4 print(f"old price before:{old_price}")
#
# NameError: name 'product' is not defined

# %% [markdown]
# ## Starting

# %%
products=soup.find_all('div')

# %%
print(products)
# Out:
# [<div id="jm"><div class="banner" data-bnrid="163" data-end="2021-12-31T23:59:00+01:00" style="background:#000;"><div class="row _no-go -phs"><a class="col16 ar _1168-56" data-creative="https://ma.jumia.is/cms/&amp;aaaa/MA_W06_STB_CSCall.gif" data-id="catalog_searchResults_MA-TopBanner-CScall_D_Summer" data-name="MA-TopBanner-CScall_D_Summer" data-position="banner_top" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.ma/sp-commandez-par-telephone/"><img alt="MA-TopBanner-CScall_D_Summer" class="_ni" data-lazy="" data-src="https://ma.jumia.is/cms/&amp;aaaa/MA_W06_STB_CSCall.gif" src="..."/></a></div></div><div class="vb row -i-ctr -j-ctr _head -bg-gy05 -gy5"><div class="col3 -df -j-start"><a class="_link -df -i-ctr -or5 -m -fs12" href="/market-place/" rel="noopener" target="_blank"><svg class="ic -f-or5 -maxs" height="16" viewbox="0 0 24 24" width="16"><use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.e70b7734.svg#cat-services"></use></sv
# ...

# %%
item=products[0]

# %%
name=item.h3

# %%
print(name)
# Out:
# <h3 class="name">Visio Smart TV 40'' Android + Récepteur Intégré +TNT + USB + HDMI + Support Mural</h3>

# %%
url=soup.find_all('div',class_='name')

# %%
print(url)
# Out:
# []

# %%
item_url=products[0]

# %%
url_link=item_url

# %%
print(url_link)
# Out:
# <div id="jm"><div class="banner" data-bnrid="163" data-end="2021-12-31T23:59:00+01:00" style="background:#000;"><div class="row _no-go -phs"><a class="col16 ar _1168-56" data-creative="https://ma.jumia.is/cms/&amp;aaaa/MA_W06_STB_CSCall.gif" data-id="catalog_searchResults_MA-TopBanner-CScall_D_Summer" data-name="MA-TopBanner-CScall_D_Summer" data-position="banner_top" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.ma/sp-commandez-par-telephone/"><img alt="MA-TopBanner-CScall_D_Summer" class="_ni" data-lazy="" data-src="https://ma.jumia.is/cms/&amp;aaaa/MA_W06_STB_CSCall.gif" src="..."/></a></div></div><div class="vb row -i-ctr -j-ctr _head -bg-gy05 -gy5"><div class="col3 -df -j-start"><a class="_link -df -i-ctr -or5 -m -fs12" href="/market-place/" rel="noopener" target="_blank"><svg class="ic -f-or5 -maxs" height="16" viewbox="0 0 24 24" width="16"><use xlink:href="https://www.jumia.ma/assets_he/images/i-icons.e70b7734.svg#cat-services"></use></svg
# ...

# %%
len(url_link)
# Out:
# 7
